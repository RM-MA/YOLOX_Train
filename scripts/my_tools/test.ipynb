# %%
import os
from pathlib import Path, PurePath
import argparse
import shutil

# %%
src_dir = '/home/www/datasets/power/robomaster'
dst_dir = '/home/www/datasets/power/all'
prefix = '1_'

src_path = Path(src_dir)
dst_path = Path(dst_dir)

# %%
# for path in src_path.iterdir():
#     # print(path)
#     print( path.stem)
#     print

for src_file in src_path.iterdir():
    print(src_file.stem)
    print(src_file.suffix)

    dst_file = dst_path / f'{prefix}{src_file.stem}{src_file.suffix}'
    print(f"src path = {src_file}")
    print(f"dst path = {dst_file}")
    
    # copy
    # shutil.copy(src=src_path, dst=dst_dir)
    
    break
# Out:
# 2023_3_28_11_24_23_770
# .txt
# src path = /home/www/datasets/power/robomaster/2023_3_28_11_24_23_770.txt
# dst path = /home/www/datasets/power/all/1_2023_3_28_11_24_23_770.txt

# %%
i = 0
for file in dst_path.iterdir():
    
    if file.stem.find("draw") != -1:
        print(file)
        os.remove(file)
        i += 1
        
print(i)
# Out:
# /home/www/datasets/power/all/6_2023_3_28_20_27_33_478.json
# /home/www/datasets/power/all/5_2023_3_27_23_30_7_476.jpg
# /home/www/datasets/power/all/4_2023_3_27_22_59_3_275.jpg
# /home/www/datasets/power/all/1_2023_3_28_11_40_8_812.json
# /home/www/datasets/power/all/3_draw2023_3_27_23_32_37_481.png
# /home/www/datasets/power/all/1_2023_3_28_11_7_47_341.txt
# /home/www/datasets/power/all/4_draw2023_3_27_22_57_55_105.png
# /home/www/datasets/power/all/6_2023_3_28_20_24_58_953.jpg
# /home/www/datasets/power/all/0_draw2023_3_28_0_39_23_75.png
# /home/www/datasets/power/all/5_2023_3_27_23_29_38_35.txt
# /home/www/datasets/power/all/1_2023_3_28_11_24_18_464.txt
# /home/www/datasets/power/all/0_2023_3_28_0_42_4_428.jpg
# /home/www/datasets/power/all/2_2023_3_28_10_47_53_536.jpg
# /home/www/datasets/power/all/1_2023_3_28_11_30_32_700.json
# /home/www/datasets/power/all/5_2023_3_27_23_15_20_861.txt
# /home/www/datasets/power/all/3_2023_3_27_23_41_11_638.jpg
# ...

# %%
t = '/home/www/datasets/power/robomaster/2023_3_28_11_24_23_770.txt'

if t.find('draw'):
    print(t)
# Out:
# /home/www/datasets/power/robomaster/2023_3_28_11_24_23_770.txt
